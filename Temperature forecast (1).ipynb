# %% [markdown]
# # Important Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the dataset

# %%
tf=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
tf.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
tf.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
tf.isna().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
tf.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(tf['Next_Tmin'])
print('Next day_Lowest min temp',tf['Next_Tmin'].min())
print('Next day_Highest min temp',tf['Next_Tmin'].max())
plt.subplot(1,2,2)
sns.histplot(tf['Next_Tmax'])
print('Next day_Lowest maximum temp',tf['Next_Tmax'].min())
print('Next day_Highest Maximum temp',tf['Next_Tmax'].max())
# Out:
# Next day_Lowest min temp 11.3
# Next day_Highest min temp 29.8
# Next day_Lowest maximum temp 17.4
# Next day_Highest Maximum temp 38.9

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(tf['Present_Tmin'])
print('Present_day_lowest_min_temp',tf['Present_Tmin'].min())
print('Present_day_highest_min_temp',tf['Present_Tmin'].max())
plt.subplot(1,2,2)
sns.histplot(tf['Present_Tmax'])
print('Present_day_lowest_max_temp',tf['Present_Tmax'].min())
print('Present_day_highest_max_temp',tf['Present_Tmax'].max())
# Out:
# Present_day_lowest_min_temp 11.3
# Present_day_highest_min_temp 29.9
# Present_day_lowest_max_temp 20.0
# Present_day_highest_max_temp 37.6

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(tf['LDAPS_RHmin'])
print('next-day lowest minimum relative humidity',tf['LDAPS_RHmin'].min())
print('next-day highest minimum relative humidity',tf['LDAPS_RHmin'].max())
plt.subplot(1,2,2)
sns.histplot(tf['LDAPS_RHmax'])
print('next-day lowest maximum relative humidity',tf['LDAPS_RHmax'].min())
print('next-day highest maximum relative humidity',tf['LDAPS_RHmax'].max())
# Out:
# next-day lowest minimum relative humidity 19.79466629
# next-day highest minimum relative humidity 98.5247345
# next-day lowest maximum relative humidity 58.93628311
# next-day highest maximum relative humidity 100.0001526

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['LDAPS_Tmin_lapse'])
print('next-day lowest min air temperature applied lapse rate',tf['LDAPS_Tmin_lapse'].min())
print('next-day highest min air temperature applied lapse rate',tf['LDAPS_Tmin_lapse'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_Tmax_lapse'])
print('next-day lowest max air temperature applied lapse rate ',tf['LDAPS_Tmax_lapse'].min())
print('next-day highest max air temperature applied lapse rate ',tf['LDAPS_Tmax_lapse'].max())
# Out:
# next-day lowest min air temperature applied lapse rate 14.27264631
# next-day highest min air temperature applied lapse rate 29.61934244
# next-day lowest max air temperature applied lapse rate  17.62495378
# next-day highest max air temperature applied lapse rate  38.54225522

# %%
print('next-day min average wind speed:',tf['LDAPS_WS'].min())
print('next-day max average wind speed:',tf['LDAPS_WS'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_LH'])
print('next-day min average latent heat flux:',tf['LDAPS_LH'].min())
print('next-day max average latent heat flux:',tf['LDAPS_LH'].max())
# Out:
# next-day min average wind speed: 2.882579625
# next-day max average wind speed: 21.85762099
# next-day min average latent heat flux: -13.60321209
# next-day max average latent heat flux: 213.4140062

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['LDAPS_CC1'])
print('next-day 1st 6-hour split min average cloud cover: ',tf['LDAPS_CC1'].min())
print('next-day 1st 6-hour split max average cloud cover: ',tf['LDAPS_CC1'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_CC2'])
print('next-day 2nd 6-hour split min average cloud cover: ',tf['LDAPS_CC2'].min())
print('next-day 2nd 6-hour split max average cloud cover: ',tf['LDAPS_CC2'].max())
# Out:
# next-day 1st 6-hour split min average cloud cover:  0.0
# next-day 1st 6-hour split max average cloud cover:  0.967277328
# next-day 2nd 6-hour split min average cloud cover:  0.0
# next-day 2nd 6-hour split max average cloud cover:  0.96835306

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['LDAPS_CC3'])
print('next-day 3rd 6-hour split min average cloud cover: ',tf['LDAPS_CC3'].min())
print('next-day 3rd 6-hour split max average cloud cover: ',tf['LDAPS_CC3'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_CC4'])
print('next-day 4th 6-hour split min average cloud cover: ',tf['LDAPS_CC4'].min())
print('next-day 4th 6-hour split max average cloud cover: ',tf['LDAPS_CC4'].max())
# Out:
# next-day 3rd 6-hour split min average cloud cover:  0.0
# next-day 3rd 6-hour split max average cloud cover:  0.983788755
# next-day 4th 6-hour split min average cloud cover:  0.0
# next-day 4th 6-hour split max average cloud cover:  0.974709524

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['LDAPS_PPT1'])
print('next-day 1st 6-hour split min average precipitation: ',tf['LDAPS_PPT1'].min())
print('next-day 1st 6-hour split max average precipitation: ',tf['LDAPS_PPT1'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_PPT2'])
print('next-day 2nd 6-hour split min average precipitation: ',tf['LDAPS_PPT2'].min())
print('next-day 2nd 6-hour split max average precipitation: ',tf['LDAPS_PPT2'].max())
# Out:
# next-day 1st 6-hour split min average precipitation:  0.0
# next-day 1st 6-hour split max average precipitation:  23.70154408
# next-day 2nd 6-hour split min average precipitation:  0.0
# next-day 2nd 6-hour split max average precipitation:  21.62166078

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['LDAPS_PPT3'])
print('next-day 3nd 6-hour split min average precipitation: ',tf['LDAPS_PPT3'].min())
print('next-day 3nd 6-hour split max average precipitation: ',tf['LDAPS_PPT3'].max())
plt.subplot(1,2,2)
sns.distplot(tf['LDAPS_PPT4'])
print('next-day 4nd 6-hour split min average precipitation: ',tf['LDAPS_PPT4'].min())
print('next-day 4nd 6-hour split max average precipitation: ',tf['LDAPS_PPT4'].max())
# Out:
# next-day 3nd 6-hour split min average precipitation:  0.0
# next-day 3nd 6-hour split max average precipitation:  15.84123484
# next-day 4nd 6-hour split min average precipitation:  0.0
# next-day 4nd 6-hour split max average precipitation:  16.65546921

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['lat'])
print('Minimum Latitude:',tf['lat'].min())
print('Maximum Latitude:',tf['lat'].max())
plt.subplot(1,2,2)
sns.distplot(tf['lon'])
print('Minimum Longitude: ',tf['lon'].min())
print('Maximum Longitude: ',tf['lon'].max())
# Out:
# Minimum Latitude: 37.4562
# Maximum Latitude: 37.645
# Minimum Longitude:  126.826
# Maximum Longitude:  127.135

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(tf['DEM'])
print('Minimum Elevation: ',tf['DEM'].min())
print('Maximum Elevation: ',tf['DEM'].max())
# Out:
# Minimum Elevation:  12.37
# Maximum Elevation:  212.335

# %%
plt.figure(figsize=(10,5))
sns.distplot(tf['Slope'])
print('Minimum Slope: ',tf['Slope'].min())
print('Maximum Slope: ',tf['Slope'].max())
# Out:
# Minimum Slope:  0.0984746
# Maximum Slope:  5.17823

# %%
plt.figure(figsize=(10,5))
sns.distplot(tf['Slope'])
print('Minimum Slope: ',tf['Slope'].min())
print('Maximum Slope: ',tf['Slope'].max())
# Out:
# Minimum Slope:  0.0984746
# Maximum Slope:  5.17823

# %%
plt.figure(figsize=(10,5))
sns.distplot(tf['Solar radiation'])
print('Minimum',tf['Solar radiation'].min())
print('Maximum',tf['Solar radiation'].max())
# Out:
# Minimum 4329.520508
# Maximum 5992.895996

# %%
tf.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.262942
# Present_Tmin       -0.365875
# LDAPS_RHmin         0.298765
# LDAPS_RHmax        -0.850870
# LDAPS_Tmax_lapse   -0.226775
# LDAPS_Tmin_lapse   -0.578943
# LDAPS_WS            1.571581
# LDAPS_LH            0.670491
# LDAPS_CC1           0.457231
# LDAPS_CC2           0.470060
# LDAPS_CC3           0.637630
# LDAPS_CC4           0.663251
# LDAPS_PPT1          5.367675
# LDAPS_PPT2          5.747360
# LDAPS_PPT3          6.425829
# LDAPS_PPT4          6.792379
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.339607
# Next_Tmin          -0.403743
# dtype: float64

# %% [markdown]
# # Outlier Detection

# %%
tf_feature=tf[['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse',
                    'LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2',
                    'LDAPS_PPT3','LDAPS_PPT4','lat','lon','DEM','Slope','Solar radiation',]]
plt.figure(figsize=(25,20),facecolor='white')
plot=1
for i in tf_feature:
    if plot<=28:
        ax=plt.subplot(4,7,plot)
        sns.boxplot(tf_feature[i])
        plt.xlabel(i,fontsize=15)
    plot+=1
plt.show()

# %%
x = tf.drop(columns=['Next_Tmax'])
y = tf['Next_Tmax']

# %%
X = tf.drop(columns=['Next_Tmin'])
Y = tf['Next_Tmin']

# %%
# plt.figure(figsize=(15,30),facecolor='white')
# plot=1
# for i in tf_feature:
#     if plot<=21:
#         ax=plt.subplot(7,3,plot)
#         sns.boxplot(tf_feature[i],y)
#         plt.xlabel(i,fontsize=15)
#         plt.ylabel('Next_Tmax',fontsize=15)
#     plot+=1
# plt.tight_layout()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='lat',y='Next_Tmax',data=tf).set_title('relation of Latitude and Next-day maximum air temperature')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='lon',y='Next_Tmax',data=tf).set_title('relation of Longitude and Next-day maximum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='DEM',y='Next_Tmax',data=tf).set_title('Relation of Elevation and Next-day maximum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Slope',y='Next_Tmax',data=tf).set_title('Relation of Slope and Next-day maximum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(15,30),facecolor='white')
# plot=1
# for i in tf_feature:
#     if plot<=21:
#         ax=plt.subplot(7,3,plot)
#         sns.boxplot(tf_feature[i],Y)
#         plt.xlabel(i,fontsize=15)
#         plt.ylabel('Next_Tmin',fontsize=15)
#     plot+=1
# plt.tight_layout()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='lat',y='Next_Tmin',data=tf).set_title('Relation of Latitude and Next-day Minimum air temperature')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='lon',y='Next_Tmin',data=tf).set_title('Relation of Longitude and Next-day Minimum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='DEM',y='Next_Tmin',data=tf).set_title('Relation of Elevation and Next-day Minimum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Slope',y='Next_Tmin',data=tf).set_title('Relation of Slope and Next-day Minimum air temperature')
plt.xticks(rotation=90)
plt.show()

# %%
drop_columns = ['station']
tf = tf.drop(columns = drop_columns,axis=1)

# %% [markdown]
# # Correlation Matrix

# %%
tf.corr()
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.618760    -0.206782    -0.304209
# Present_Tmin          0.618760      1.000000     0.124921    -0.015334
# LDAPS_RHmin          -0.206782      0.124921     1.000000     0.579141
# LDAPS_RHmax          -0.304209     -0.015334     0.579141     1.000000
# LDAPS_Tmax_lapse      0.575289      0.470118    -0.564580    -0.373404
# LDAPS_Tmin_lapse      0.629247      0.772921     0.089476    -0.114143
# LDAPS_WS             -0.122876     -0.035111     0.294361     0.135333
# LDAPS_LH              0.136716     -0.009368    -0.070858     0.238579
# LDAPS_CC1            -0.314863      0.085593     0.613818     0.436652
# LDAPS_CC2            -0.215816      0.091439     0.745443     0.391330
# LDAPS_CC3            -0.145513     -0.002839     0.689679     0.226957
# LDAPS_CC4            -0.142497     -0.045091     0.514075     0.130619
# ...

# %% [markdown]
# # Plotting Heatmap

# %%
plt.figure(figsize=(22,16))
sns.heatmap(tf.corr(),cbar=True,cmap='rainbow',vmin=-1,vmax=1,square=True,fmt='.2g',annot=True,
            center=True,annot_kws={'size':10},linewidths=.1,linecolor='white')
plt.show()

# %%
plt.figure(figsize=(10,5))
tf.corr()['Next_Tmax'].sort_values(ascending=False).drop(['Next_Tmax']).plot(kind='bar',color='r')
plt.xlabel('Continuous Features',fontsize=14)
plt.ylabel('Column with label',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10,5))
tf.corr()['Next_Tmin'].sort_values(ascending=False).drop(['Next_Tmin']).plot(kind='bar',color='r')
plt.xlabel('Continuous Features',fontsize=14)
plt.ylabel('Column with label',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# Removing presence of missing values in columns by using knnImputer.

# %%
from sklearn.impute import KNNImputer
k=KNNImputer(n_neighbors=2)
tf['Next_Tmax']=k.fit_transform(tf[['Next_Tmax']])
tf['Next_Tmin']=k.fit_transform(tf[['Next_Tmin']])
tf['Present_Tmax']=k.fit_transform(tf[['Present_Tmax']])
tf['Present_Tmin']=k.fit_transform(tf[['Present_Tmin']])
tf['LDAPS_RHmin']=k.fit_transform(tf[['LDAPS_RHmin']])
tf['LDAPS_RHmax']=k.fit_transform(tf[['LDAPS_RHmax']])
tf['LDAPS_Tmax_lapse']=k.fit_transform(tf[['LDAPS_Tmax_lapse']])
tf['LDAPS_Tmin_lapse']=k.fit_transform(tf[['LDAPS_Tmin_lapse']])
tf['LDAPS_WS']=k.fit_transform(tf[['LDAPS_WS']])
tf['LDAPS_LH']=k.fit_transform(tf[['LDAPS_LH']])
tf['LDAPS_CC1']=k.fit_transform(tf[['LDAPS_CC1']])
tf['LDAPS_CC2']=k.fit_transform(tf[['LDAPS_CC2']])
tf['LDAPS_CC3']=k.fit_transform(tf[['LDAPS_CC3']])
tf['LDAPS_CC4']=k.fit_transform(tf[['LDAPS_CC4']])
tf['LDAPS_PPT1']=k.fit_transform(tf[['LDAPS_PPT1']])
tf['LDAPS_PPT2']=k.fit_transform(tf[['LDAPS_PPT2']])
tf['LDAPS_PPT3']=k.fit_transform(tf[['LDAPS_PPT3']])
tf['LDAPS_PPT4']=k.fit_transform(tf[['LDAPS_PPT4']])

# %%
tf.isna().sum()
# Out:
# Date                2
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
tf.dropna(inplace=True) 
tf.isna().sum()
# Out:
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
from scipy.stats import zscore
z_score = zscore(tf[['Present_Tmax','Present_Tmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse',
                       'LDAPS_WS','LDAPS_LH','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope']])     
abs_z_score=np.abs(z_score)#converting data into standard normal distribution

filtering_entry=(abs_z_score<3.5).all(axis=1)

# %%
tf.skew()
# Out:
# Present_Tmax       -0.263013
# Present_Tmin       -0.357565
# LDAPS_RHmin         0.300229
# LDAPS_RHmax        -0.850657
# LDAPS_Tmax_lapse   -0.224207
# LDAPS_Tmin_lapse   -0.579033
# LDAPS_WS            1.556422
# LDAPS_LH            0.667582
# LDAPS_CC1           0.459193
# LDAPS_CC2           0.471965
# LDAPS_CC3           0.640088
# LDAPS_CC4           0.665829
# LDAPS_PPT1          5.324404
# LDAPS_PPT2          5.713247
# LDAPS_PPT3          6.368693
# LDAPS_PPT4          6.743231
# lat                 0.086942
# lon                -0.285300
# DEM                 1.723944
# Slope               1.563346
# Solar radiation    -0.511006
# Next_Tmax          -0.335956
# Next_Tmin          -0.396873
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
features=['LDAPS_RHmax','LDAPS_WS','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope']
scaler=PowerTransformer(method='yeo-johnson')   # using yeo-johnson method
tf[features]=scaler.fit_transform(tf[features].values) # scaling the features
tf[features]
# Out:
#       LDAPS_RHmax  LDAPS_WS  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0        0.273088  0.093945  -0.584914   -0.570465   -0.532412   -0.505636
# 1        0.185961 -0.626414  -0.603710   -0.570465   -0.532412   -0.505636
# 2       -0.773874 -0.315052  -0.520214   -0.570465   -0.532412   -0.505636
# 3        1.317400 -0.657654  -0.565558   -0.570465   -0.532412   -0.505636
# 4        0.111060 -0.594612  -0.365807   -0.570465   -0.532412   -0.505636
# ...           ...       ...        ...         ...         ...         ...
# 7745    -1.384521 -0.028024  -1.446078   -0.570465   -0.532412   -0.505636
# 7746    -0.808505 -0.570477  -1.342730   -0.570465   -0.532412   -0.505636
# 7747    -1.327658 -0.308049  -1.480882   -0.570465   -0.532412   -0.505636
# 7748    -1.471163 -0.063406  -1.480882   -0.570465   -0.532412   -0.505636
# 7749    -1.475633  0.338850  -1.474527   -0.570465   -0.532412   -0.505636
#
#       LDAPS_PPT4       DEM     Slope
# ...

# %%
data_features=tf[['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse',
                    'LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2',
                    'LDAPS_PPT3','LDAPS_PPT4','lat','lon','DEM','Slope','Solar radiation',]]
plt.figure(figsize=(15,30),facecolor='white')  
plot=1
for i in data_features:                    
    if plot<=21:
        ax=plt.subplot(7,3,plot)
        sns.distplot(data_features[i],kde=True)
        plt.xlabel(i,fontsize=20)
    plot+=1
plt.show()

# %%
import datetime as dt

# %%
tf['year'] = pd.DatetimeIndex(tf['Date']).year 
tf['month'] = pd.DatetimeIndex(tf['Date']).month 
tf['day'] = pd.DatetimeIndex(tf['Date']).day
tf.head()
# Out:
#          Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0  30-06-2013          28.7          21.4    58.255688     0.273088
# 1  30-06-2013          31.9          21.6    52.263397     0.185961
# 2  30-06-2013          31.6          23.3    48.690479    -0.773874
# 3  30-06-2013          32.0          23.4    58.239788     1.317400
# 4  30-06-2013          31.4          21.9    56.174095     0.111060
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  0.093945   69.451805   0.233947  ...
# 1         29.850689         24.035009 -0.626414   51.937448   0.225508  ...
# 2         30.091292         24.565633 -0.315052   20.573050   0.209344  ...
# 3         29.704629         23.326177 -0.657654   65.727144   0.216372  ...
# 4         29.113934         23.486480 -0.594612  107.965535   0.151407  ...
#
#        lat      lon       DEM     Slope  Solar radiation  Next_Tmax  \
# ...

# %%
tf.drop(['Date'],axis=1,inplace=True)

# %%
tf['year'].replace(2013,1,inplace=True)
tf['year'].replace(2014,2,inplace=True)
tf['year'].replace(2015,3,inplace=True)
tf['year'].replace(2016,4,inplace=True)
tf['year'].replace(2017,5,inplace=True)

# %%
tf['Time']=(tf['year']*365)+(tf['month']*30)+(tf['day'])

# %%
tf.drop(['year','month','day'],axis=1,inplace=True)

# %%
tf.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          28.7          21.4    58.255688     0.273088         28.074101
# 1          31.9          21.6    52.263397     0.185961         29.850689
# 2          31.6          23.3    48.690479    -0.773874         30.091292
# 3          32.0          23.4    58.239788     1.317400         29.704629
# 4          31.4          21.9    56.174095     0.111060         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.006936  0.093945   69.451805   0.233947   0.203896  ...
# 1         24.035009 -0.626414   51.937448   0.225508   0.251771  ...
# 2         24.565633 -0.315052   20.573050   0.209344   0.257469  ...
# 3         23.326177 -0.657654   65.727144   0.216372   0.226002  ...
# 4         23.486480 -0.594612  107.965535   0.151407   0.249995  ...
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM     Slope  \
# ...

# %%
x=tf.drop(columns=['Next_Tmax'])
y=tf['Next_Tmax']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
scaled_value=ss.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(scaled_value,i)for i in range(scaled_value.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#          vif          Features
# 0   2.867455      Present_Tmax
# 1   3.485502      Present_Tmin
# 2   6.696557       LDAPS_RHmin
# 3   2.601490       LDAPS_RHmax
# 4   7.718581  LDAPS_Tmax_lapse
# 5   9.145853  LDAPS_Tmin_lapse
# 6   1.251338          LDAPS_WS
# 7   1.518877          LDAPS_LH
# 8   4.996826         LDAPS_CC1
# 9   6.054187         LDAPS_CC2
# 10  5.636559         LDAPS_CC3
# 11  2.964942         LDAPS_CC4
# 12  2.614209        LDAPS_PPT1
# 13  2.370833        LDAPS_PPT2
# 14  1.948879        LDAPS_PPT3
# 15  1.863373        LDAPS_PPT4
# 16  1.236052               lat
# 17  1.224904               lon
# 18  2.970932               DEM
# 19  2.760368             Slope
# 20  1.252644   Solar radiation
# 21  5.825220         Next_Tmin
# 22  1.130268              Time

# %% [markdown]
# # Principle Component Analysis

# %%
from sklearn import decomposition
from sklearn.decomposition import PCA

# %%
pca=PCA()
pca.fit_transform(scaled_value)
# Out:
# array([[-0.42059973,  1.99078965,  2.37502151, ..., -0.04610792,
#          0.12850368, -0.31461959],
#        [-1.30055997,  0.40138461,  0.7852436 , ..., -0.09273767,
#          0.13170166, -0.23179322],
#        [-1.65089392, -0.56210958, -0.1032478 , ...,  0.19023271,
#          0.10359521, -0.23147852],
#        ...,
#        [-2.13476424,  4.60257807, -3.46652547, ...,  0.37941453,
#         -0.27846751, -0.6235134 ],
#        [-2.25777783,  4.3469761 , -3.38420469, ...,  0.52250892,
#         -0.2479838 , -0.47873046],
#        [-2.15810335,  4.66585093, -3.27612206, ...,  0.0932949 ,
#         -0.21789642, -0.28605099]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal Component')
plt.ylabel('Variance Covered')
plt.title('Principle Component Analysis',color='darkblue')
plt.show()

# %% [markdown]
# # Model Creation

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):   
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1*100)
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean()*100)
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std()*100)
    print('Training accuracy',clf.score(x_train,y_train)*100)
    print('Test Accuracy',clf.score(x_test,y_test)*100)
    print('MAE',mean_absolute_error(y_test,pred))
    print('MSE',mean_squared_error(y_test,pred))
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    print('\n')
    sns.regplot(pred,y_test)
    
    
    return final_r

# %%
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 90 is 81.09598216230918
# cross validation score 70.64859521676422
# Standard Deviation 6.445729722005177
# Training accuracy 79.0322914228304
# Test Accuracy 77.7444914726755
# MAE 1.1232583128152098
# MSE 2.137731022306943
# RMSE 1.4620981575485767
# 90

# %%
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 90 is 74.48728943617775
# cross validation score 65.49682376659722
# Standard Deviation 5.023754711592273
# Training accuracy 72.78922541685606
# Test Accuracy 72.13228950768395
# MAE 1.259325391551222
# MSE 2.6768055722901285
# RMSE 1.6360946098224665
# 90

# %%
rigde=Ridge()
maxr2_score(rigde,x,y)
# Out:
# max r2 score corresponding to 90 is 81.09343234809006
# cross validation score 70.65442933742972
# Standard Deviation 6.452099640573532
# Training accuracy 79.03213701229525
# Test Accuracy 77.7447967575761
# MAE 1.123130974742122
# MSE 2.1377016984655293
# RMSE 1.4620881295139254
# 90

# %%
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 82 is 83.01725225297926
# cross validation score 38.62340140133939
# Standard Deviation 19.553936203939756
# Training accuracy 100.0
# Test Accuracy 81.34206672865653
# MAE 0.9611607057104081
# MSE 1.7921694630034477
# RMSE 1.3387193369050316
# 82

# %%
# knn=KNeighborsRegressor()
# maxr2_score(knn,x,y)

# %%
# svm=SVR()
# maxr2_score(svm,x,y)

# %%
# rf=RandomForestRegressor()
# maxr2_score(rf,x,y)

# %%
Adb=AdaBoostRegressor(base_estimator=lasso)
maxr2_score(Adb,x,y)
# Out:
# max r2 score corresponding to 51 is 74.85703058710347
# cross validation score 64.67559397796998
# Standard Deviation 7.3881142397512996
# Training accuracy 72.8794491939927
# Test Accuracy 71.88626819993036
# MAE 1.2814497734980128
# MSE 2.7004369074756482
# RMSE 1.6433006138487407
# 51

# %%
gnb=GradientBoostingRegressor()
maxr2_score(gnb,x,y)
# Out:
# max r2 score corresponding to 87 is 87.94266307162437
# cross validation score 71.09998004481872
# Standard Deviation 7.597326705156907
# Training accuracy 88.81681382660346
# Test Accuracy 86.17806049234893
# MAE 0.8860264789762337
# MSE 1.3276528297557522
# RMSE 1.1522381827364307
# 87

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=75,test_size=.20)
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],'solver': ['auto', 'svd', 'cholesky', 'lsqr']}
glf=GridSearchCV(estimator=ridge,param_grid=parameters,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'alpha': 1, 'solver': 'auto'}

# %%
ridge1=Ridge(alpha=1,solver='svd')
ridge1.fit(x_train,y_train)
pred=ridge1.predict(x_test)
print('Training accuracy',ridge1.score(x_train,y_train)*100)
print('Test Accuracy',ridge1.score(x_test,y_test)*100)
print('\n')

print('Error:')
print('MAE',mean_absolute_error(y_test,pred))
print('MSE',mean_squared_error(y_test,pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('R2 score',r2_score(pred,y_test)*100)
# Out:
# Training accuracy 78.88798446904906
# Test Accuracy 78.23397253415114
#
#
# Error:
# MAE 1.099524422484616
# MSE 2.061157749107685
# RMSE 1.4356732738014193
# R2 score 71.6436760666302

# %% [markdown]
# # Save the model

# %%
import joblib
joblib.dump(ridge1,'temp.pkl')
# Out:
# ['temp.pkl']

# %%
loaded_model=joblib.load('temp.pkl')
prediction=loaded_model.predict(x_test)

# %%
prediction
# Out:
# array([32.11777358, 30.98357467, 26.70338234, ..., 32.76989163,
#        29.96655834, 32.05217166])
