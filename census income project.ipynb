# %% [markdown]
# # Import Important Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Load the data.

# %%
cs=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
cs.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
cs.shape
# Out:
# (32560, 15)

# %% [markdown]
# Dataset contains 32560 rows and 15 columns.

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
cs.isna().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# There is no null values present in the dataset.

# %% [markdown]
# # Statistical Summary.

# %%
cs.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# This dataset is having 0 nulll values.

# %% [markdown]
# Min age is 17 years in the census.

# %% [markdown]
# Max age is 90 years in the dataset.

# %% [markdown]
# Capital gain and Capital loss is containing lots of 0 values.

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cs.isnull())
# Out:
# <AxesSubplot:>

# %%
cs.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cs.corr(),annot=True)
plt.show()

# %% [markdown]
# Segregation of categorical and numerical columns:

# %%
cs1=cs.select_dtypes(exclude='object')
cs1
# Out:
#        Age  Fnlwgt  Education_num  Capital_gain  Capital_loss  Hours_per_week
# 0       50   83311             13             0             0              13
# 1       38  215646              9             0             0              40
# 2       53  234721              7             0             0              40
# 3       28  338409             13             0             0              40
# 4       37  284582             14             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32555   27  257302             12             0             0              38
# 32556   40  154374              9             0             0              40
# 32557   58  151910              9             0             0              40
# 32558   22  201490              9             0             0              20
# 32559   52  287927              9         15024             0              40
#
# [32560 rows x 6 columns]

# %%
cs2=cs.select_dtypes(include='object')
cs2
# Out:
#                Workclass    Education       Marital_status  \
# 0       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1                Private      HS-grad             Divorced
# 2                Private         11th   Married-civ-spouse
# 3                Private    Bachelors   Married-civ-spouse
# 4                Private      Masters   Married-civ-spouse
# ...                  ...          ...                  ...
# 32555            Private   Assoc-acdm   Married-civ-spouse
# 32556            Private      HS-grad   Married-civ-spouse
# 32557            Private      HS-grad              Widowed
# 32558            Private      HS-grad        Never-married
# 32559       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native_country  \
# 0         Exec-managerial         Husband   White     Male   United-States
# 1       Handlers-cleaners   Not-in-family   White     Male   United-States
# ...

# %% [markdown]
# # Exploratory Data Analysis.

# %%
#working type analysis
plt.figure(figsize=(20,10))

sns.barplot(y='Age',x='Workclass',data= cs)
plt.show()

# %%
# plt.figure(figsize=(20,10))

# sns.barplot(y='Age',x='Fnlwgt',data= cs)
# plt.show()

# %%
cs['Sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.title('Age vs Sex',fontsize=20,color='m')
sns.scatterplot(y='Age',x='Relationship',data= cs)
plt.show()

# %%
#Age vs Sex
plt.figure(figsize=(10,5))
plt.title('Age vs Sex',fontsize=20,color='m')

sns.barplot(y='Age',x='Sex',data= cs)
plt.show()

# %%
#Educational analysis
plt.figure(figsize=(20,10))
sns.boxenplot(x='Education_num',y='Age',data=cs)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.title('Workclass vs Hours_per_week',fontsize=20,color='b')

sns.pointplot(x='Workclass',y='Hours_per_week',data= cs)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.title('Capital_gain vs Capital_loss',fontsize=20,color='b')

sns.lineplot(x='Capital_loss',y='Capital_gain',data= cs)
plt.show()

# %% [markdown]
# Removing useless data in the dataset.

# %%
cs2.replace("?",'np.nan')
# Out:
#                Workclass    Education       Marital_status  \
# 0       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1                Private      HS-grad             Divorced
# 2                Private         11th   Married-civ-spouse
# 3                Private    Bachelors   Married-civ-spouse
# 4                Private      Masters   Married-civ-spouse
# ...                  ...          ...                  ...
# 32555            Private   Assoc-acdm   Married-civ-spouse
# 32556            Private      HS-grad   Married-civ-spouse
# 32557            Private      HS-grad              Widowed
# 32558            Private      HS-grad        Never-married
# 32559       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native_country  \
# 0         Exec-managerial         Husband   White     Male   United-States
# 1       Handlers-cleaners   Not-in-family   White     Male   United-States
# ...

# %%
cs.shape
# Out:
# (32560, 15)

# %% [markdown]
# # Data Distribution:

# %%
cs1=cs.select_dtypes(exclude='object')
plt.figure(figsize=(20,20))
plot=1
for i in cs1:
    if plot<=13:
        plt.subplot(2,3,plot)
        sns.distplot(cs[i],rug=True,color='Darkorange')
        plt.xlabel(i)
        plot=plot+1
plt.show();

# %% [markdown]
# # Outlier Detection:

# %%
plt.figure(figsize=(15,12))
plot=1
for i in cs1:
    
    if plot<=15:
        plt.subplot(2,3,plot)
        sns.boxplot(cs[i],color='red')
        plt.xlabel(i)
        plot=plot+1
plt.show();

# %%
cs.shape
# Out:
# (32560, 15)

# %% [markdown]
# Outliers removal using IQR method.

# %%
def outlier(data,i):
        IQR=data[i].quantile(.75)-data[i].quantile(.25)
        lower_side=data[i].quantile(.25)-(IQR*1.5)
        upper_side=data[i].quantile(.75)+(IQR*1.5)
        non_outlier=np.where((data[i]<lower_side )|(data[i]>upper_side),data[i].median(),data[i])
        data[i]=non_outlier
        sns.boxplot(data[i])

# %%
cs.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# # Skewness.

# %%
plt.figure(figsize=(15,12))
plot=1
for i in cs1:
    if plot<=15:
        plt.subplot(2,3,plot)
        sns.distplot(cs[i],rug=True,color='Darkblue')
        plt.xlabel(i)
        plot=plot+1
plt.show();

# %%
cs1.drop(['Capital_gain','Capital_loss'],axis=1,inplace=True)

# %%
cs1.skew()
# Out:
# Age               0.558738
# Fnlwgt            1.446972
# Education_num    -0.311630
# Hours_per_week    0.227636
# dtype: float64

# %%
cs1['Hours_per_week']=np.log1p(cs['Hours_per_week'])

# %%
cs1.skew()
# Out:
# Age               0.558738
# Fnlwgt            1.446972
# Education_num    -0.311630
# Hours_per_week   -2.357666
# dtype: float64

# %% [markdown]
# # Encoder.

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
for i in cs2:
    cs2[i]=le.fit_transform(cs2[i])

# %%
cs2.head()
# Out:
#    Workclass  Education  Marital_status  Occupation  Relationship  Race  Sex  \
# 0          6          9               2           4             0     4    1
# 1          4         11               0           6             1     4    1
# 2          4          1               2           6             0     2    1
# 3          4          9               2          10             5     2    0
# 4          4         12               2           4             5     4    0
#
#    Native_country  Income
# 0              39       0
# 1              39       0
# 2              39       0
# 3               5       0
# 4              39       0

# %%
data=[cs1,cs2]

# %% [markdown]
# concatenating categorical and numerical columns after encoding.

# %%
cs=cs1.join(cs2)

# %%
cs.head()
# Out:
#    Age  Fnlwgt  Education_num  Hours_per_week  Workclass  Education  \
# 0   50   83311             13        2.639057          6          9
# 1   38  215646              9        3.713572          4         11
# 2   53  234721              7        3.713572          4          1
# 3   28  338409             13        3.713572          4          9
# 4   37  284582             14        3.713572          4         12
#
#    Marital_status  Occupation  Relationship  Race  Sex  Native_country  Income
# 0               2           4             0     4    1              39       0
# 1               0           6             1     4    1              39       0
# 2               2           6             0     2    1              39       0
# 3               2          10             5     2    0               5       0
# 4               2           4             5     4    0              39       0

# %% [markdown]
# # Dropping Target Variable.

# %%
x=cs.drop(['Income'],axis=1)
y=cs[['Income']]

# %%
x
# Out:
#        Age  Fnlwgt  Education_num  Hours_per_week  Workclass  Education  \
# 0       50   83311             13        2.639057          6          9
# 1       38  215646              9        3.713572          4         11
# 2       53  234721              7        3.713572          4          1
# 3       28  338409             13        3.713572          4          9
# 4       37  284582             14        3.713572          4         12
# ...    ...     ...            ...             ...        ...        ...
# 32555   27  257302             12        3.663562          4          7
# 32556   40  154374              9        3.713572          4         11
# 32557   58  151910              9        3.713572          4         11
# 32558   22  201490              9        3.044522          4         11
# 32559   52  287927              9        3.713572          5         11
#
#        Marital_status  Occupation  Relationship  Race  Sex  Native_country
# ...

# %%
y
# Out:
#        Income
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 32555       0
# 32556       1
# 32557       0
# 32558       0
# 32559       1
#
# [32560 rows x 1 columns]

# %% [markdown]
# # Scaler.

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
scaled_value=ss.fit_transform(x)

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()
extra.fit(x,y)
plt.figure(figsize=(15,6))
plt.title('Feature Classification',fontsize=15,)
feature=pd.Series(extra.feature_importances_,index=x.columns)
feature.plot(kind='barh',color='Purple')
plt.show();

# %% [markdown]
# # Important libaries for ml model creation.

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,auc,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %% [markdown]
# Splitting x and y in 75% of train and 25% of testing data.

# %%
x_train, x_test ,y_train, y_test = train_test_split(x,y,test_size=.25,random_state=40)

# %% [markdown]
# # Model creation:

# %%
def accuracy(clf,x,y):   
    max_accuracy=0
    for i in range(42,100):
        clf.fit(x_train,y_train)
        pred = clf.predict(x_test)
        accuracy_s = accuracy_score(y_test,pred)
        if accuracy_s > max_accuracy:
            max_accuracy = accuracy_s
            result = i
    
    print('max_accuracy_score',result,'is',max_accuracy*100)
    print('cross validation score',cross_val_score(clf,x,y,scoring='accuracy').mean()*100)
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='accuracy').std()*100)
    print('Training accuracy',clf.score(x_train,y_train)*100)
    print('Test Accuracy',clf.score(x_test,y_test)*100)
    print('Confusion_Matrix',confusion_matrix(y_test,pred))
    print('Classification_Report',classification_report(y_test,pred))
    
    print('Roc_auc Score',roc_auc_score(y_test,pred))
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,pred)
    roc_auc = auc( false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate,label = "AUC = %0.2f"% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc = 'lower right')
    plt.ylabel("True positive rate")
    plt.xlabel("False positive rate")
    print("\n\n")
    
    
    return result

# %%
lg=LogisticRegression()
accuracy(lg,x,y)
# Out:
# max_accuracy_score 42 is 75.87223587223588
# cross validation score 75.91830466830467
# Standard Deviation 0.006142506142507997
# Training accuracy 75.93366093366093
# Test Accuracy 75.87223587223588
# Confusion_Matrix [[6176    0]
#  [1964    0]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      6176
#            1       0.00      0.00      0.00      1964
#
#     accuracy                           0.76      8140
#    macro avg       0.38      0.50      0.43      8140
# weighted avg       0.58      0.76      0.65      8140
#
# Roc_auc Score 0.5
# 42

# %%
dt=DecisionTreeClassifier()
accuracy(dt,x,y)
# Out:
# max_accuracy_score 58 is 78.43980343980344
# cross validation score 77.45700245700245
# Standard Deviation 0.36463936313650663
# Training accuracy 99.995904995905
# Test Accuracy 78.39066339066339
# Confusion_Matrix [[5279  897]
#  [ 862 1102]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      6176
#            1       0.55      0.56      0.56      1964
#
#     accuracy                           0.78      8140
#    macro avg       0.71      0.71      0.71      8140
# weighted avg       0.79      0.78      0.78      8140
#
# Roc_auc Score 0.7079300795141564
# 58

# %%
knn=KNeighborsClassifier()
accuracy(knn,x,y)
# Out:
# max_accuracy_score 42 is 71.90417690417691
# cross validation score 71.98402948402949
# Standard Deviation 0.32598714712126325
# Training accuracy 80.05733005733006
# Test Accuracy 71.90417690417691
# Confusion_Matrix [[5458  718]
#  [1569  395]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      6176
#            1       0.35      0.20      0.26      1964
#
#     accuracy                           0.72      8140
#    macro avg       0.57      0.54      0.54      8140
# weighted avg       0.67      0.72      0.69      8140
#
# Roc_auc Score 0.5424318431244262
# 42

# %%
# sv=SVC()  #too slow to response.
# accuracy(sv,x,y)

# %%
rf=RandomForestClassifier()
accuracy(rf,x,y)
# Out:
# max_accuracy_score 96 is 83.37837837837839
# cross validation score 82.75184275184276
# Standard Deviation 0.5198135517869461
# Training accuracy 99.99180999180999
# Test Accuracy 82.81326781326781
# Confusion_Matrix [[5628  548]
#  [ 851 1113]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      6176
#            1       0.67      0.57      0.61      1964
#
#     accuracy                           0.83      8140
#    macro avg       0.77      0.74      0.75      8140
# weighted avg       0.82      0.83      0.82      8140
#
# Roc_auc Score 0.7389850205248883
# 96

# %%
Adb=AdaBoostClassifier()
accuracy(Adb,x,y)
# Out:
# max_accuracy_score 42 is 83.992628992629
# cross validation score 83.67628992628994
# Standard Deviation 0.6228664784209657
# Training accuracy 83.71826371826371
# Test Accuracy 83.992628992629
# Confusion_Matrix [[5734  442]
#  [ 861 1103]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      6176
#            1       0.71      0.56      0.63      1964
#
#     accuracy                           0.84      8140
#    macro avg       0.79      0.75      0.76      8140
# weighted avg       0.83      0.84      0.83      8140
#
# Roc_auc Score 0.7450208018952544
# 42

# %%
gnb=GradientBoostingClassifier()
accuracy(gnb,x,y)
# Out:
# max_accuracy_score 44 is 84.04176904176904
# cross validation score 84.0970515970516
# Standard Deviation 0.5085312539513298
# Training accuracy 84.51678951678952
# Test Accuracy 84.04176904176904
# Confusion_Matrix [[5756  420]
#  [ 879 1085]]
# Classification_Report               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      6176
#            1       0.72      0.55      0.63      1964
#
#     accuracy                           0.84      8140
#    macro avg       0.79      0.74      0.76      8140
# weighted avg       0.83      0.84      0.83      8140
#
# Roc_auc Score 0.7422194052531051
# 44

# %% [markdown]
# # Hyperparameter Tuning-

# %%
dt = DecisionTreeClassifier()
grid_param={
       'criterion':['entropy','gini'],
       'max_depth':(10,15),
       'min_samples_split':(10,12),
       'min_samples_leaf':(4,5),
       'max_leaf_nodes':(5,7) }

grd= GridSearchCV(estimator=dt,
                  param_grid=grid_param,
                  cv=5,  
                  n_jobs=-1)
           
            
grd.fit(x_train,y_train)
print('best_params=> ',grd.best_params_)

dt=grd.best_estimator_ 
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

dt_conf_mat = confusion_matrix(y_test,y_pred)
print('con_mat=> ','\n',dt_conf_mat)
print('Accuracy of dt After Hyperparameter Tuning==> ',accuracy_score(y_test,y_pred)*100)
# Out:
# best_params=>  {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# con_mat=>
#  [[5927  249]
#  [1248  716]]
# Accuracy of dt After Hyperparameter Tuning==>  81.60933660933661

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(dt,'census.pkl')
# Out:
# ['census.pkl']

# %%
loaded_model=joblib.load('census.pkl')
prediction=loaded_model.predict(x_test)

# %%
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 1])
