# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Loading Data:

# %%
bb=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
bb.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
bb.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset has 30 rows and 17 columns.

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Info indicates that there is float and 16 integer type values.

# %%
bb.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Plotting heatmap for for null values.

# %%
sns.heatmap(bb.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values present in the dataset.

# %% [markdown]
# # Statistical Data Analysis:

# %%
bb.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Exploratory Data Analysis:

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'W', y= 'CG',data=bb)
plt.title('Win vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'R', y= 'CG',data=bb)
plt.title('Runs vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'AB', y= 'CG',data=bb)
plt.title('At_Bats vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'H', y= 'CG',data=bb)
plt.title('Hits vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= '2B', y= 'CG',data=bb)
plt.title('Doubles vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= '3B', y= 'CG',data=bb)
plt.title('Triples vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'HR', y= 'CG',data=bb)
plt.title('HomeRuns vs Complete Game',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'BB', y= 'CG',data=bb)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'SO', y= 'CG',data=bb)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= 'RA', y= 'CG',data=bb)
plt.show()

# %% [markdown]
# # Data Distribution:

# %%
oex=bb.select_dtypes(include=['int64','float64'])
plt.figure(figsize=(18,15))
p=1
for i in bb:
    if p<=17:
        plt.subplot(5,5,p)
        sns.histplot(bb[i],color='Purple')
        plt.ylabel(i)
        p=p+1
plt.show();

# %% [markdown]
# # Outliers Detection:

# %%
plt.figure(figsize=(18,15))
p=1
for i in oex:
    if p<=17:
        plt.subplot(5,5,p)
        sns.boxplot(bb[i],color='Darkorange',orient='v')
        plt.ylabel(i)
        p=p+1
plt.show();

# %%
from scipy.stats import zscore
z =np.abs(zscore(oex))
print(z.shape)
bb =bb.loc[(z<3).all(axis=1)]
print(bb.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# # Skewness:

# %%
bb.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# # Removing Skewness using log1p method:

# %%
for i in oex:
    if bb[i].skew()>.55:
        bb[i]=np.log1p(bb[i])
        
plt.figure(figsize=(18,15))
p=1
for i in oex:
    if p<=17:
        plt.subplot(5,5,p)
        sns.boxplot(bb[i],color='LightGreen')
        plt.ylabel(i)
        p=p+1
plt.show();

# %%
bb.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %%
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# for i in bb:
#     bb[i]=le.fit_transform(bb[i])

# %% [markdown]
# # Target Variable:

# %%
x=bb.drop(['W'],axis=1)
y=bb[['W']]

# %%
x.head(2)
# Out:
#      R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0  724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1  696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
#
#          CG  SHO        SV         E
# 0  1.098612    8  4.043051  4.488636
# 1  1.098612   12  3.828641  4.465908

# %%
y.head(2)
# Out:
#     W
# 0  95
# 1  83

# %% [markdown]
# # Scaling:

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
scaled_value=ss.fit_transform(x)
x=pd.DataFrame(scaled_value,columns=x.columns)
x.head(5)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.240415 -0.813262
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.240415  0.159299
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  1.815711 -0.326982
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.214333 -0.570122
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.214333  0.159299
#
#          SV         E
# 0  1.554812 -0.435733
# 1  0.296229 -0.598110
# 2 -0.672787 -1.197382
# ...

# %% [markdown]
# # Feature Importance:

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()
extra.fit(x,y)
plt.figure(figsize=(15,6))
plt.title('Feature Classification',fontsize=15,)
feature=pd.Series(extra.feature_importances_,index=x.columns)
feature.plot(kind='bar',color='Darkorange')
plt.show();

# %% [markdown]
# # Splitting data for training and testing:

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):   
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1*100)
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean()*100)
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std()*100)
    print('Training accuracy',clf.score(x_train,y_train)*100)
    print('Test Accuracy',clf.score(x_test,y_test)*100)
    print('MAE',mean_absolute_error(y_test,pred))
    print('MSE',mean_squared_error(y_test,pred))
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    print('\n')
    sns.regplot(pred,y_test)
    
    return final_r

# %% [markdown]
# # Logistic Regression:

# %%
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 73 is 85.07709590470472
# cross validation score 4.078645834638232
# Standard Deviation 44.73773492059169
# Training accuracy 96.32661736539144
# Test Accuracy 84.90901108769991
# MAE 4.442997113976799
# MSE 23.022141973986706
# RMSE 4.798139428360404
# 73

# %% [markdown]
# # Lasso:

# %%
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 82 is 95.69861780928952
# cross validation score 49.03382482134098
# Standard Deviation 60.02031960611405
# Training accuracy 85.96965906875516
# Test Accuracy 87.52922811726906
# MAE 3.810352441874779
# MSE 19.024855327766215
# RMSE 4.361749113345037
# 82

# %% [markdown]
# # Ridge:

# %%
rigde=Ridge()
maxr2_score(rigde,x,y)
# Out:
# max r2 score corresponding to 75 is 96.5647042561389
# cross validation score 39.17445799642074
# Standard Deviation 68.38140520964888
# Training accuracy 93.2603770205697
# Test Accuracy 91.96126869876205
# MAE 3.0388280178362983
# MSE 12.263531196221889
# RMSE 3.5019324945266845
# 75

# %% [markdown]
# # Decision Tree:

# %%
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 65 is 77.08484408992024
# cross validation score -215.9277229314009
# Standard Deviation 356.9347525275293
# Training accuracy 100.0
# Test Accuracy 71.92279679533867
# MAE 5.5
# MSE 42.833333333333336
# RMSE 6.544717972023954
# 65

# %% [markdown]
# # KNN:

# %%
knn=KNeighborsRegressor()
maxr2_score(knn,x,y)
# Out:
# max r2 score corresponding to 51 is 79.73065326633166
# cross validation score 2.711156066932061
# Standard Deviation 78.88810870744435
# Training accuracy 61.82682583105365
# Test Accuracy 66.4340859431901
# MAE 6.633333333333333
# MSE 51.20666666666668
# RMSE 7.1558833603313206
# 51

# %% [markdown]
# # SVM:

# %%
svm=SVR()
maxr2_score(svm,x,y)
# Out:
# max r2 score corresponding to 54 is 22.178358793156285
# cross validation score -29.720223502747977
# Standard Deviation 49.177877863138775
# Training accuracy 21.985396844426752
# Test Accuracy 15.457624455188334
# MAE 9.978375554568848
# MSE 128.97409069225156
# RMSE 11.356676040649022
# 54

# %% [markdown]
# # Random Forest:

# %%
rf=RandomForestRegressor()
maxr2_score(rf,x,y)
# Out:
# max r2 score corresponding to 94 is 79.76975881261592
# cross validation score -53.61095382862893
# Standard Deviation 218.5543344995026
# Training accuracy 92.49315883279449
# Test Accuracy 71.51331755280405
# MAE 5.728333333333336
# MSE 43.45801666666671
# RMSE 6.592269462534636
# 94

# %% [markdown]
# # AdaBoost:

# %%
Adb=AdaBoostRegressor(base_estimator=lasso)
maxr2_score(Adb,x,y)
# Out:
# max r2 score corresponding to 75 is 93.59679778481058
# cross validation score 33.6506364420433
# Standard Deviation 67.49112047862371
# Training accuracy 86.96556222061066
# Test Accuracy 87.90786069261064
# MAE 3.154020595344908
# MSE 18.447230298939544
# RMSE 4.295023899693638
# 75

# %% [markdown]
# # GradientBoost:

# %%
gnb=GradientBoostingRegressor()
maxr2_score(gnb,x,y)
# Out:
# max r2 score corresponding to 94 is 85.15317748482958
# cross validation score -139.71841392961545
# Standard Deviation 370.5384194974883
# Training accuracy 99.99998270821823
# Test Accuracy 67.09294314285796
# MAE 6.119748773856355
# MSE 50.20154340539556
# RMSE 7.085304750354466
# 94

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=75,test_size=.20)
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],'solver': ['auto', 'svd', 'cholesky', 'lsqr']}
glf=GridSearchCV(estimator=ridge,param_grid=parameters,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'alpha': 1, 'solver': 'svd'}

# %%
ridge1=Ridge(alpha=1,solver='svd')
ridge1.fit(x_train,y_train)
pred=ridge1.predict(x_test)
print('Training accuracy',ridge1.score(x_train,y_train)*100)
print('Test Accuracy',ridge1.score(x_test,y_test)*100)
print('\n')

print('Error:')
print('MAE',mean_absolute_error(y_test,pred))
print('MSE',mean_squared_error(y_test,pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('R2 score',r2_score(pred,y_test)*100)
# Out:
# Training accuracy 91.79210449221075
# Test Accuracy 96.5647042561389
#
#
# Error:
# MAE 1.717957231883311
# MSE 4.642420498301201
# RMSE 2.154627693663386
# R2 score 96.62212521645058

# %%
import joblib
joblib.dump(ridge1,'baseballR_1.pkl')
# Out:
# ['baseballR_1.pkl']

# %%
loaded_model=joblib.load('baseballR_1.pkl')
prediction=loaded_model.predict(x_test)

# %%
prediction
# Out:
# array([[81.71244245],
#        [67.95344847],
#        [72.30037652],
#        [87.15699317],
#        [64.36478711],
#        [98.24776944]])
